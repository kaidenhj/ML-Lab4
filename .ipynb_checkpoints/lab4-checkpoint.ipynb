# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import pandas as pd

# %%
# reads the data from the file

#df = pd.read_csv('/Users/kaidenjones/Desktop/localify_lab4_data.tsv', sep='\t')
df = pd.read_csv('/Users/cymoar/COMP-ML/Labs/ML-Lab4/localify_music_genre-song_dataset_short_limited.tsv', sep='\t')

# Slpits the data into training and validation data
df_training = df.iloc[:8000]
df_validation = df.iloc[8000:]

# spit the data into labels, X, y
training_label_df = df_training[['song_name','artist_name']]
tensor_label = tf.convert_to_tensor(training_label_df)
training_X_df = df_training[['acousticness','danceability','energy','instrumentalness',
                             'liveness','loudness','speechiness','tempo','valence']]
tensor_training_X = tf.convert_to_tensor(training_X_df)
training_y_df = df_training[['genre_name','Unnamed: 12']]

# tensor_training_y1 = tf.convert_to_tensor(training_y_df[['genre_name']])
tensor_training_y = tf.convert_to_tensor(training_y_df[['Unnamed: 12']], dtype=tf.float32)
tty2 = tf.convert_to_tensor(training_y_df[['Unnamed: 12']])
vector_y = tf.reshape(tty2, [8000])

validation_label_df = df_validation[['song_name','artist_name']]
validation_X_df = df_validation[['acousticness','danceability','energy','instrumentalness','liveness',
                                 'loudness','speechiness','tempo','valence']]
validation_y_df = df_validation[['genre_name','Unnamed: 12']]

# %%
# Model archecture
# model = Sequential([
#     Dense(units=25, activation="relu"),
#     Dense(units=15, activation="relu"),
#     Dense(units=10 , activation="linear")])

new_lambda_value = .0001

model = Sequential([
    Dense(units=10, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(new_lambda_value)),
    Dense(units=20, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(new_lambda_value)),
    Dense(units=30, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(new_lambda_value)),
    Dense(units=40, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(new_lambda_value)),
    Dense(units=50, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(new_lambda_value)),
    Dense(units=50, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(new_lambda_value)),
    Dense(units=40, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(new_lambda_value)),
    Dense(units=30, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(new_lambda_value)),
    Dense(units=20, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(new_lambda_value)),
    Dense(units=10 , activation="linear", kernel_regularizer=tf.keras.regularizers.l2(new_lambda_value))])

# %%
# gets the loss
#model.compile(optimizer='sgd', loss=SparseCategoricalCrossentropy(from_logits = True))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer='adam', loss=SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
# makes the model fit
model.fit(tensor_training_X, tensor_training_y, epochs=100)
# Out:
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 749us/step - accuracy: 0.1296 - loss: 2.3366
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.1691 - loss: 2.2433
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.1734 - loss: 2.2302
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.1706 - loss: 2.2232
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.1739 - loss: 2.2106
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.1656 - loss: 2.2155
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.1624 - loss: 2.2145
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.1778 - loss: 2.2117
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.1846 - loss: 2.2013
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.1830 - loss: 2.1813
# Epoch 11/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.1867 - loss: 2.1856
# Epoch 12/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.1843 - loss: 2.1771
# Epoch 13/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.1909 - loss: 2.1859
# Epoch 14/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.1833 - loss: 2.1811
# Epoch 15/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.2007 - loss: 2.1532
# Epoch 16/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.2112 - loss: 2.1555
# Epoch 17/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.2043 - loss: 2.1490
# Epoch 18/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.2103 - loss: 2.1437
# Epoch 19/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.2137 - loss: 2.1467
# Epoch 20/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.2215 - loss: 2.1160
# Epoch 21/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.2256 - loss: 2.1046
# Epoch 22/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.2383 - loss: 2.0853
# Epoch 23/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.2362 - loss: 2.0914
# Epoch 24/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.2419 - loss: 2.0835
# Epoch 25/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - accuracy: 0.2441 - loss: 2.0857
# Epoch 26/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.2317 - loss: 2.0815
# Epoch 27/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.2438 - loss: 2.1000
# Epoch 28/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.2550 - loss: 2.0651
# Epoch 29/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.2537 - loss: 2.0445
# Epoch 30/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.2507 - loss: 2.0586
# Epoch 31/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.2446 - loss: 2.0795
# Epoch 32/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.2596 - loss: 2.0357
# Epoch 33/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.2636 - loss: 2.0468
# Epoch 34/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.2592 - loss: 2.0327
# Epoch 35/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.2598 - loss: 2.0347
# Epoch 36/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.2602 - loss: 2.0347
# Epoch 37/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - accuracy: 0.2564 - loss: 2.0577
# Epoch 38/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - accuracy: 0.2655 - loss: 2.0327
# Epoch 39/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.2648 - loss: 2.0100
# Epoch 40/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.2682 - loss: 2.0059
# Epoch 41/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - accuracy: 0.2692 - loss: 2.0060
# Epoch 42/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.2688 - loss: 2.0034
# Epoch 43/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.2577 - loss: 2.0046
# Epoch 44/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.2755 - loss: 1.9997
# Epoch 45/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.2519 - loss: 2.0182
# Epoch 46/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.2666 - loss: 2.0126
# Epoch 47/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.2849 - loss: 1.9839
# Epoch 48/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - accuracy: 0.2715 - loss: 1.9844
# Epoch 49/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.2716 - loss: 1.9976
# Epoch 50/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.2849 - loss: 1.9837
# Epoch 51/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - accuracy: 0.2796 - loss: 1.9953
# Epoch 52/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.2758 - loss: 1.9897
# Epoch 53/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.2781 - loss: 1.9731
# Epoch 54/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.2882 - loss: 1.9738
# Epoch 55/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.2963 - loss: 1.9625
# Epoch 56/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.2962 - loss: 1.9575
# Epoch 57/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.2885 - loss: 1.9670
# Epoch 58/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.2911 - loss: 1.9612
# Epoch 59/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.2917 - loss: 1.9567
# Epoch 60/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.2959 - loss: 1.9570
# Epoch 61/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 0.3021 - loss: 1.9531
# Epoch 62/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.3017 - loss: 1.9632
# Epoch 63/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - accuracy: 0.2910 - loss: 1.9567
# Epoch 64/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.3098 - loss: 1.9452
# Epoch 65/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.2824 - loss: 1.9711
# Epoch 66/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.2983 - loss: 1.9441
# Epoch 67/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - accuracy: 0.3054 - loss: 1.9489
# Epoch 68/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.2958 - loss: 1.9499
# Epoch 69/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.3059 - loss: 1.9324
# Epoch 70/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.2997 - loss: 1.9715
# Epoch 71/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.3058 - loss: 1.9490
# Epoch 72/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.2974 - loss: 1.9507
# Epoch 73/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.3062 - loss: 1.9479
# Epoch 74/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.2961 - loss: 1.9582
# Epoch 75/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.3015 - loss: 1.9405
# Epoch 76/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.3095 - loss: 1.9442
# Epoch 77/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.3072 - loss: 1.9318
# Epoch 78/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.3003 - loss: 1.9443
# Epoch 79/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - accuracy: 0.3052 - loss: 1.9492
# Epoch 80/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.3026 - loss: 1.9484
# Epoch 81/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.2997 - loss: 1.9372
# Epoch 82/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.3058 - loss: 1.9336
# Epoch 83/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - accuracy: 0.2998 - loss: 1.9420
# Epoch 84/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.3087 - loss: 1.9267
# Epoch 85/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.3062 - loss: 1.9332
# Epoch 86/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - accuracy: 0.3059 - loss: 1.9409
# Epoch 87/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.3023 - loss: 1.9300
# Epoch 88/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 0.2977 - loss: 1.9445
# Epoch 89/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.3023 - loss: 1.9233
# Epoch 90/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.3076 - loss: 1.9420
# Epoch 91/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.3071 - loss: 1.9388
# Epoch 92/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.3067 - loss: 1.9394
# Epoch 93/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.3050 - loss: 1.9304
# Epoch 94/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.3100 - loss: 1.9355
# Epoch 95/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - accuracy: 0.3032 - loss: 1.9499
# Epoch 96/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.3067 - loss: 1.9283
# Epoch 97/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.2926 - loss: 1.9555
# Epoch 98/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.3075 - loss: 1.9198
# Epoch 99/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.2984 - loss: 1.9564
# Epoch 100/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.3057 - loss: 1.9457

# %%
# gets the predictions of the model
logits = model(tensor_training_X)
f_x = tf.nn.softmax(logits)

# %%
print(f_x)
# Out:
# tf.Tensor(
# [[0.10321535 0.0577748  0.17632148 ... 0.16390826 0.02456059 0.05010163]
#  [0.2860083  0.05771898 0.01801679 ... 0.13126211 0.20050064 0.01142871]
#  [0.2548251  0.10829823 0.01425886 ... 0.0760235  0.11936748 0.02593311]
#  ...
#  [0.13965507 0.1981784  0.0110024  ... 0.03860742 0.02472048 0.10947231]
#  [0.27655447 0.08818203 0.00510556 ... 0.08071852 0.20347516 0.05024549]
#  [0.22611989 0.05137041 0.02605849 ... 0.25605905 0.13346729 0.04056448]], shape=(8000, 10), dtype=float32)

# %%
predictions = tf.argmax(f_x, axis=1)
sum_vector = tf.reduce_sum(predictions)

# %%
correct_predictions = tf.equal(predictions, vector_y)
accuracy = tf.reduce_mean(tf.cast(correct_predictions, tf.float32))
print(correct_predictions)
print(accuracy)
print(vector_y)
# Out:
# tf.Tensor([False  True  True ... False False False], shape=(8000,), dtype=bool)
# tf.Tensor(0.3155, shape=(), dtype=float32)
# tf.Tensor([0 0 0 ... 5 8 8], shape=(8000,), dtype=int64)

# %%
conf_matrix = tf.math.confusion_matrix(labels=vector_y, predictions=predictions)
print(conf_matrix)
# Out:
# tf.Tensor(
# [[330 201  84  51   0  25  77 151 132 104]
#  [151 415  51  51   0  28  52  57   9 130]
#  [ 29   9 671   9   0  10  60  59   2   5]
#  [188 251  22 133   0  20  51  47   5  23]
#  [201 192  46  33   0  25  40  74  57  69]
#  [ 95 190 166  62   0  34  87  90   6  73]
#  [ 75 124 266  50   0  26 111  90   3  46]
#  [128  28 154  21   0   8  50 301  22  54]
#  [163  20  17  10   0   4   6  76 207  15]
#  [ 38 182  43  13   0  13  22  58   1 322]], shape=(10, 10), dtype=int32)
